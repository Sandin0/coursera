# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Sara Sandino**
# Meteorologist

# %% [markdown]
# *I am interested in Data Science because I want to be able to extract useful information from data*

# %% [markdown]
# ### This code will generate a random number between 0 and 10

# %%
import random

Random_int = random.randint(0,10)

print(Random_int)
# Out:
# 7

# %% [markdown]
# * 1
# - 2
# + 3
#
# 1. one
# 2. two
# 4. three
#
# Just | a | table
# --- | --- | ---
# 1 | 2 | 3
